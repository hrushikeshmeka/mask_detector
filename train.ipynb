# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split

data=np.load('data.npy')
target=np.load('target.npy')

model=Sequential()

model.add(Conv2D(100,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(50,activation='relu'))
model.add(Dense(2,activation='softmax'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

checkpoint = ModelCheckpoint(
  'model-{epoch:03d}.model',
  monitor='val_loss',
  verbose=0,
  save_best_only=True,
  mode='auto')

history=model.fit(
  train_data,
  train_target,
  epochs=20,
  callbacks=[checkpoint],
  validation_split=0.2)

print(model.evaluate(test_data,test_target))
# Out:
# Epoch 1/20
# 23/23 [==============================] - 15s 624ms/step - loss: 0.6886 - accuracy: 0.5862 - val_loss: 0.4350 - val_accuracy: 0.8232
# INFO:tensorflow:Assets written to: model-001.model\assets
# Epoch 2/20
# 23/23 [==============================] - 13s 577ms/step - loss: 0.4076 - accuracy: 0.8132 - val_loss: 0.3775 - val_accuracy: 0.8122
# INFO:tensorflow:Assets written to: model-002.model\assets
# Epoch 3/20
# 23/23 [==============================] - 14s 620ms/step - loss: 0.3491 - accuracy: 0.8557 - val_loss: 0.4085 - val_accuracy: 0.8066
# Epoch 4/20
# 23/23 [==============================] - 14s 614ms/step - loss: 0.3027 - accuracy: 0.8896 - val_loss: 0.3931 - val_accuracy: 0.8177
# Epoch 5/20
# 23/23 [==============================] - 15s 654ms/step - loss: 0.2553 - accuracy: 0.8862 - val_loss: 0.3972 - val_accuracy: 0.8122
# Epoch 6/20
# 23/23 [==============================] - 15s 653ms/step - loss: 0.1717 - accuracy: 0.9306 - val_loss: 0.3990 - val_accuracy: 0.8122
# Epoch 7/20
# 23/23 [==============================] - 15s 637ms/step - loss: 0.1477 - accuracy: 0.9500 - val_loss: 0.5262 - val_accuracy: 0.7956
# Epoch 8/20
# 23/23 [==============================] - 14s 589ms/step - loss: 0.1180 - accuracy: 0.9696 - val_loss: 0.5358 - val_accuracy: 0.7790
# Epoch 9/20
# 23/23 [==============================] - 14s 619ms/step - loss: 0.0961 - accuracy: 0.9717 - val_loss: 0.5719 - val_accuracy: 0.8122
# Epoch 10/20
# 23/23 [==============================] - 14s 595ms/step - loss: 0.0592 - accuracy: 0.9843 - val_loss: 0.6984 - val_accuracy: 0.7845
# Epoch 11/20
# 23/23 [==============================] - 14s 594ms/step - loss: 0.0391 - accuracy: 0.9896 - val_loss: 0.6038 - val_accuracy: 0.7956
# Epoch 12/20
# 23/23 [==============================] - 14s 613ms/step - loss: 0.0370 - accuracy: 0.9948 - val_loss: 0.7458 - val_accuracy: 0.8122
# Epoch 13/20
# 23/23 [==============================] - 16s 707ms/step - loss: 0.0552 - accuracy: 0.9855 - val_loss: 0.7509 - val_accuracy: 0.8122
# Epoch 14/20
# 23/23 [==============================] - 16s 708ms/step - loss: 0.0208 - accuracy: 0.9940 - val_loss: 0.6916 - val_accuracy: 0.8177
# Epoch 15/20
# 23/23 [==============================] - 16s 697ms/step - loss: 0.0258 - accuracy: 0.9951 - val_loss: 0.8771 - val_accuracy: 0.7845
# Epoch 16/20
# 23/23 [==============================] - 14s 594ms/step - loss: 0.0248 - accuracy: 0.9929 - val_loss: 0.7778 - val_accuracy: 0.8066
# Epoch 17/20
# 23/23 [==============================] - 15s 638ms/step - loss: 0.0193 - accuracy: 0.9994 - val_loss: 0.8297 - val_accuracy: 0.8066
# Epoch 18/20
# 23/23 [==============================] - 16s 692ms/step - loss: 0.0097 - accuracy: 0.9991 - val_loss: 1.1066 - val_accuracy: 0.7901
# Epoch 19/20
# 23/23 [==============================] - 15s 662ms/step - loss: 0.0423 - accuracy: 0.9848 - val_loss: 1.0346 - val_accuracy: 0.7790
# Epoch 20/20
# 23/23 [==============================] - 14s 597ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.1422 - val_accuracy: 0.7790
# 4/4 [==============================] - 0s 109ms/step - loss: 1.1737 - accuracy: 0.8119
# [1.1737087965011597, 0.8118811845779419]
